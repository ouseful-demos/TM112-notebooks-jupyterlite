# %% [markdown]
# # ACTIVITIES — READ ME FIRST
#
# A series of interactive notebooks are provided
#
# Open an activity notebook by double-clicking the file name in the file listing in the left hand sidebar.
#
# See the notebook `Using Jupyter Notebooks.ipunb` for examples on how to work with Jupyter notebooks.
